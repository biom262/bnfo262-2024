# %% [markdown]
# # Intro to Bioinformatics Applications of R

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# Let's practice using R to analyze some data using data manipulation and visualizations. We will use publicly-available data ([GSE166925](https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSE166925)) from NCBI GEO with inflammatory bowel disease and colorectal cancer patients.
#
# <br><br>
# RNA-seq data usually comes with two files:
# <ul>
# <li> a metadata file with information about the samples (ex: sample ID, disease status, gender, etc.) where each row represents a sample and columns contain the various information </li>
# <li> a gene expression file with the gene expression information for each sample where the rows represent the genes and the columns represent the samples </li>
# </ul>
# </div>

# %% [markdown]
# First, let's get the metadata using the [`GEOquery`](https://bioconductor.org/packages/devel/bioc/vignettes/GEOquery/inst/doc/GEOquery.html) library.

# %% [markdown]
# ### Libraries
# Every time you load a library you're adding a new environment to R. The library specific functions become available because R searches all environments for your function call. Sometimes you override an existing function by loading a new library. You can reference the package-specific function via the package specifier.
#
# Note: You can also suppress the messages printed when loading a library using [`suppressPackageStartupMessages()`](https://www.geeksforgeeks.org/how-to-disable-messages-when-loading-a-package-in-r/).

# %% [markdown]
# One of the benefits of using libraries is you don't need to rewrite code that already exists! We can use the `getGEO()` function from the `GEOquery` library to automatically get the data from GEO instead of manually trying to get the sample information.
#
# The code is provided here, but we won't run it:

# %% [markdown]
#     # Get data
#     suppressPackageStartupMessages(library(GEOquery))
#
#     #Sys.setenv(VROOM_CONNECTION_SIZE=500072) # Might need to change to have enough buffer to download  file
#     gse <- getGEO(GEO='GSE166925',destdir='data/')

# %% [markdown]
# Using the gse object we created, we can get the sample information/metadata and store it in a `meta` dataframe we can later refer to.

# %% [markdown]
#     # Generate data frame for metadata
#     gse_data <- gse[[1]]
#
#     columns <- c("title","disease:ch1","gender:ch1", "inflammation_status:ch1", "nancy_score:ch1",
#                     "patient_age:ch1","site_taken:ch1")
#
#     meta <- pData(gse_data)[, which((names(pData(gse_data)) %in% columns)==TRUE)]
#
#     # Save metadata table to file for later use
#     write.table(meta, "data/GSE166925-meta.tsv", sep='\t',quote=FALSE)

# %% [markdown]
# The metadata file is located here: `data/GSE166925-meta.tsv`
# <br><br>
#
# Now we need the gene expression file. This is available for download on the GSE166925 NCBI GEO page under Supplementary file. To get this file, you can either click on the http link to locally download it, or use the ftp link to download it on the server.
#
# The terminal command to get the data is :
#
# `wget https://ftp.ncbi.nlm.nih.gov/geo/series/GSE166nnn/GSE166925/suppl/GSE166925_salmon.genes.tpms.txt.gz`
#
# This file was already downloaded onto DataHub and is available here:
#
# `~/public/module-1-programming/data/GSE166925_salmon.genes.tpms.txt.gz`

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <p>We now have both the metadata and gene expression files ready to analyze.</p>
#
# </div>

# %% [markdown]
# ### Data Manipulation
# We need to format the data in a way that we can use for later analyses/visualizations.

# %% [markdown]
# Let's read in the sample metadata table that was saved to GSE166925-meta.tsv (file location: `~/module-1-programming/data/GSE166925-meta.tsv`) into a `meta` dataframe object. We can use the [`read.table()`](https://www.rdocumentation.org/packages/utils/versions/3.6.2/topics/read.table) function to generate dataframes from files.

# %%
meta <- read.table('GSE166925-meta.tsv',sep='\t')
head(meta)
# Out:
#            title        disease.ch1 gender.ch1 inflammation_status.ch1
# GSM5088383 UC_I_LI_M_1  UC          male       inflamed
# GSM5088385 UC_NA_LI_F_2 UC          female     inflamed
# GSM5088387 CD_I_SI_F_3  CD          female     inflamed
# GSM5088389 CD_I_SI_M_4  CD          male       inflamed
# GSM5088391 CD_I_LI_M_5  CD          male       inflamed
# GSM5088392 CD_U_LI_M_6  CD          male       uninflamed
#            nancy_score.ch1 patient_age.ch1 site_taken.ch1
# GSM5088383  2              56              large_intestine
# GSM5088385  4              63              large_intestine
# GSM5088387  4              56              small_intestine
# GSM5088389 NA              33              small_intestine
# GSM5088391  2              28              large_intestine
# GSM5088392 NA              55              large_intestine

# %% [markdown]
# Let's also use the title column as the index instead of the GSM IDs using `rownames()`.

# %%
rownames(meta) <- meta$title
head(meta)
# Out:
#              title        disease.ch1 gender.ch1 inflammation_status.ch1
# UC_I_LI_M_1  UC_I_LI_M_1  UC          male       inflamed
# UC_NA_LI_F_2 UC_NA_LI_F_2 UC          female     inflamed
# CD_I_SI_F_3  CD_I_SI_F_3  CD          female     inflamed
# CD_I_SI_M_4  CD_I_SI_M_4  CD          male       inflamed
# CD_I_LI_M_5  CD_I_LI_M_5  CD          male       inflamed
# CD_U_LI_M_6  CD_U_LI_M_6  CD          male       uninflamed
#              nancy_score.ch1 patient_age.ch1 site_taken.ch1
# UC_I_LI_M_1   2              56              large_intestine
# UC_NA_LI_F_2  4              63              large_intestine
# CD_I_SI_F_3   4              56              small_intestine
# CD_I_SI_M_4  NA              33              small_intestine
# CD_I_LI_M_5   2              28              large_intestine
# CD_U_LI_M_6  NA              55              large_intestine

# %% [markdown]
# Now let's read in the gene expression data table from the file GSE166925_salmon.genes.tpms.txt.gz into an `expr` dataframe. (file location: `~/public/module-1-programming/data/GSE166925_salmon.genes.tpms.txt.gz`)

# %%
expr <- read.table('GSE166925_salmon.genes.tpms.txt.gz',header=TRUE)
head(expr)
# Out:
#   gene_id         CD_I_LI_F_22 CD_I_LI_F_29 CD_I_LI_M_15 CD_I_LI_M_24
# 1 ENSG00000000003 5.094850     2.955470     1.848870      3.802330
# 2 ENSG00000000005 0.433639     0.205504     0.000000      0.000000
# 3 ENSG00000000419 4.234940     3.350510     2.427460      2.880860
# 4 ENSG00000000457 0.586098     0.425931     0.501005      0.411644
# 5 ENSG00000000460 0.344564     0.579495     0.483984      0.258893
# 6 ENSG00000000938 6.478880     3.278080     8.245220     12.607800
#   CD_I_LI_M_36 CD_I_LI_M_49 CD_I_LI_M_5 CD_I_SI_F_20 CD_I_SI_F_25 ⋯
# 1 10.161400     3.467200    5.025920    8.968070     3.502050     ⋯
# 2  0.604877     0.000000    0.120606    0.250889     0.000000     ⋯
# 3  2.305760     7.085010    3.347020    5.985330     3.147280     ⋯
# 4  0.529764     0.400366    0.651770    0.747979     0.301862     ⋯
# 5  0.122450     0.000000    0.495650    0.146662     0.000000     ⋯
# 6  1.262730    11.969700    2.134260    2.014500     1.779640     ⋯
#   UC_I_LI_F_45 UC_I_LI_F_8 UC_I_LI_M_1 UC_I_LI_M_34 UC_I_LI_M_9 UC_M_LI_F_18
# 1  1.903170    3.108230    3.445030     3.172990    4.513300    3.855490
# 2  0.037813    0.166965    0.000000     0.626974    0.060215    0.202251
# 3  4.002100    5.209190    2.981830     4.407800    5.677800    4.117850
# 4  0.369654    0.671137    0.362387     1.007640    0.855920    0.138235
# 5  0.204045    0.344391    0.624086     0.399062    0.319007    0.126902
# 6 10.377400    9.366620    7.472590    12.876000    8.059280    1.073340
#   UC_NA_LI_F_2 UC_U_LI_F_40 UC_U_LI_M_33 UC_U_SI_F_17
# 1 5.914390     5.358530     10.344300    5.411630
# 2 0.000000     0.259292      0.091125    0.045819
# 3 4.468820     4.909960      5.736400    3.649040
# 4 0.219709     0.722102      0.330994    0.276997
# 5 0.287883     0.300087      0.136381    0.280994
# 6 7.508690     4.989870      2.754170    1.312720

# %% [markdown]
# We'll review this more in the RNA-seq module but when looking at gene expression data, we usually use the log normalized expression for analysis. The file provided already has normalized data (TPM in given in the filename), so we can take the log using `apply()`.

# %%
expr[-1] <- lapply(expr[-1], log1p)
head(expr)
# Out:
#   gene_id         CD_I_LI_F_22 CD_I_LI_F_29 CD_I_LI_M_15 CD_I_LI_M_24
# 1 ENSG00000000003 1.8074442    1.3750994    1.0469224    1.5691012
# 2 ENSG00000000005 0.3602160    0.1868977    0.0000000    0.0000000
# 3 ENSG00000000419 1.6553554    1.4702931    1.2318195    1.3560568
# 4 ENSG00000000457 0.4612769    0.3548249    0.4061349    0.3447550
# 5 ENSG00000000460 0.2960698    0.4571052    0.3947304    0.2302328
# 6 ENSG00000000938 2.0120830    1.4535043    2.2241067    2.6106432
#   CD_I_LI_M_36 CD_I_LI_M_49 CD_I_LI_M_5 CD_I_SI_F_20 CD_I_SI_F_25 ⋯
# 1 2.4124614    1.4967618    1.7960702   2.2993870    1.5045328    ⋯
# 2 0.4730471    0.0000000    0.1138696   0.2238545    0.0000000    ⋯
# 3 1.1956664    2.0900117    1.4694906   1.9438122    1.4224527    ⋯
# 4 0.4251135    0.3367336    0.5018474   0.5584603    0.2637955    ⋯
# 5 0.1155138    0.0000000    0.4025609   0.1368551    0.0000000    ⋯
# 6 0.8165720    2.5626159    1.1423931   1.1034340    1.0223214    ⋯
#   UC_I_LI_F_45 UC_I_LI_F_8 UC_I_LI_M_1 UC_I_LI_M_34 UC_I_LI_M_9 UC_M_LI_F_18
# 1 1.06580324   1.4129923   1.4917866   1.4286328    1.70716335  1.5801100
# 2 0.03711561   0.1544064   0.0000000   0.4867218    0.05847172  0.1841956
# 3 1.60985782   1.8260305   1.3817415   1.6878424    1.89878859  1.6327344
# 4 0.31455815   0.5135042   0.3092383   0.6969599    0.61838053  0.1294788
# 5 0.18568672   0.2959411   0.4849452   0.3358020    0.27687918  0.1194723
# 6 2.43162893   2.3385910   2.1368362   2.6301607    2.20378965  0.7291608
#   UC_NA_LI_F_2 UC_U_LI_F_40 UC_U_LI_M_33 UC_U_SI_F_17
# 1 1.9336047    1.8497972    2.42871542   1.85811353
# 2 0.0000000    0.2305497    0.08720927   0.04480031
# 3 1.6990629    1.7766391    1.90752566   1.53666075
# 4 0.1986123    0.5435456    0.28592603   0.24451123
# 5 0.2529998    0.2624312    0.12784865   0.24763634
# 6 2.1410880    1.7900697    1.32286722   0.83842432

# %% [markdown]
# The provided file only has the gene IDs (ENSG IDs) but it's easier to use the gene names/symbols, so let's find a library that can add the gene names.

# %%
suppressPackageStartupMessages(library(EnsDb.Hsapiens.v79))
geneIDs <- ensembldb::select(EnsDb.Hsapiens.v79, keys= expr$gene_id, keytype = "GENEID", columns = c("GENEID","SYMBOL"))
head(geneIDs)
# Out:
#   GENEID          SYMBOL
# 1 ENSG00000000003 TSPAN6
# 2 ENSG00000000005 TNMD
# 3 ENSG00000000419 DPM1
# 4 ENSG00000000457 SCYL3
# 5 ENSG00000000460 C1orf112
# 6 ENSG00000000938 FGR

# %% [markdown]
# This created a new dataframe `geneIDs` with matching ENSG IDs and gene names. To get the gene names into our `expr` dataframe, we can use the `merge()` function.
#
# The [`merge()`](https://www.rdocumentation.org/packages/base/versions/3.6.2/topics/merge) function allows you to merge two dataframes by specifying columns that are matching.
#
# In the example of our two dataframes, the 'gene_id' column in the `expr` dataframe and the 'GENEID' column in the `geneIDs` dataframes both contain the ENSG IDs, so we can merge on those columns and create a new dataframe `expr2` which has the gene names and gene expression.

# %%
expr2 <- merge(geneIDs,expr, by.x='GENEID', by.y='gene_id')
head(expr2)
# Out:
#   GENEID          SYMBOL   CD_I_LI_F_22 CD_I_LI_F_29 CD_I_LI_M_15 CD_I_LI_M_24
# 1 ENSG00000000003 TSPAN6   1.8074442    1.3750994    1.0469224    1.5691012
# 2 ENSG00000000005 TNMD     0.3602160    0.1868977    0.0000000    0.0000000
# 3 ENSG00000000419 DPM1     1.6553554    1.4702931    1.2318195    1.3560568
# 4 ENSG00000000457 SCYL3    0.4612769    0.3548249    0.4061349    0.3447550
# 5 ENSG00000000460 C1orf112 0.2960698    0.4571052    0.3947304    0.2302328
# 6 ENSG00000000938 FGR      2.0120830    1.4535043    2.2241067    2.6106432
#   CD_I_LI_M_36 CD_I_LI_M_49 CD_I_LI_M_5 CD_I_SI_F_20 ⋯ UC_I_LI_F_45 UC_I_LI_F_8
# 1 2.4124614    1.4967618    1.7960702   2.2993870    ⋯ 1.06580324   1.4129923
# 2 0.4730471    0.0000000    0.1138696   0.2238545    ⋯ 0.03711561   0.1544064
# 3 1.1956664    2.0900117    1.4694906   1.9438122    ⋯ 1.60985782   1.8260305
# 4 0.4251135    0.3367336    0.5018474   0.5584603    ⋯ 0.31455815   0.5135042
# 5 0.1155138    0.0000000    0.4025609   0.1368551    ⋯ 0.18568672   0.2959411
# 6 0.8165720    2.5626159    1.1423931   1.1034340    ⋯ 2.43162893   2.3385910
#   UC_I_LI_M_1 UC_I_LI_M_34 UC_I_LI_M_9 UC_M_LI_F_18 UC_NA_LI_F_2 UC_U_LI_F_40
# 1 1.4917866   1.4286328    1.70716335  1.5801100    1.9336047    1.8497972
# 2 0.0000000   0.4867218    0.05847172  0.1841956    0.0000000    0.2305497
# 3 1.3817415   1.6878424    1.89878859  1.6327344    1.6990629    1.7766391
# 4 0.3092383   0.6969599    0.61838053  0.1294788    0.1986123    0.5435456
# 5 0.4849452   0.3358020    0.27687918  0.1194723    0.2529998    0.2624312
# 6 2.1368362   2.6301607    2.20378965  0.7291608    2.1410880    1.7900697
#   UC_U_LI_M_33 UC_U_SI_F_17
# 1 2.42871542   1.85811353
# 2 0.08720927   0.04480031
# 3 1.90752566   1.53666075
# 4 0.28592603   0.24451123
# 5 0.12784865   0.24763634
# 6 1.32286722   0.83842432

# %% [markdown]
# To make the `expr2` dataframe match the format of the `meta` dataframe (rows with samples), we can use the `t()` function which transposes the data, essentially switching the rows and columns.
#
# First, let's remove the "GENEID" column from `expr2`.

# %%
expr2 <- expr2[,-c(1)]
head(expr2)
# Out:
#   SYMBOL   CD_I_LI_F_22 CD_I_LI_F_29 CD_I_LI_M_15 CD_I_LI_M_24 CD_I_LI_M_36
# 1 TSPAN6   1.8074442    1.3750994    1.0469224    1.5691012    2.4124614
# 2 TNMD     0.3602160    0.1868977    0.0000000    0.0000000    0.4730471
# 3 DPM1     1.6553554    1.4702931    1.2318195    1.3560568    1.1956664
# 4 SCYL3    0.4612769    0.3548249    0.4061349    0.3447550    0.4251135
# 5 C1orf112 0.2960698    0.4571052    0.3947304    0.2302328    0.1155138
# 6 FGR      2.0120830    1.4535043    2.2241067    2.6106432    0.8165720
#   CD_I_LI_M_49 CD_I_LI_M_5 CD_I_SI_F_20 CD_I_SI_F_25 ⋯ UC_I_LI_F_45 UC_I_LI_F_8
# 1 1.4967618    1.7960702   2.2993870    1.5045328    ⋯ 1.06580324   1.4129923
# 2 0.0000000    0.1138696   0.2238545    0.0000000    ⋯ 0.03711561   0.1544064
# 3 2.0900117    1.4694906   1.9438122    1.4224527    ⋯ 1.60985782   1.8260305
# 4 0.3367336    0.5018474   0.5584603    0.2637955    ⋯ 0.31455815   0.5135042
# 5 0.0000000    0.4025609   0.1368551    0.0000000    ⋯ 0.18568672   0.2959411
# 6 2.5626159    1.1423931   1.1034340    1.0223214    ⋯ 2.43162893   2.3385910
#   UC_I_LI_M_1 UC_I_LI_M_34 UC_I_LI_M_9 UC_M_LI_F_18 UC_NA_LI_F_2 UC_U_LI_F_40
# 1 1.4917866   1.4286328    1.70716335  1.5801100    1.9336047    1.8497972
# 2 0.0000000   0.4867218    0.05847172  0.1841956    0.0000000    0.2305497
# 3 1.3817415   1.6878424    1.89878859  1.6327344    1.6990629    1.7766391
# 4 0.3092383   0.6969599    0.61838053  0.1294788    0.1986123    0.5435456
# 5 0.4849452   0.3358020    0.27687918  0.1194723    0.2529998    0.2624312
# 6 2.1368362   2.6301607    2.20378965  0.7291608    2.1410880    1.7900697
#   UC_U_LI_M_33 UC_U_SI_F_17
# 1 2.42871542   1.85811353
# 2 0.08720927   0.04480031
# 3 1.90752566   1.53666075
# 4 0.28592603   0.24451123
# 5 0.12784865   0.24763634
# 6 1.32286722   0.83842432

# %% [markdown]
# Now let's use `t()` and `data.frame()` to transpose the `expr2` dataframe.

# %%
expr2 <- data.frame(t(expr2))
head(expr2)
# Out:
#              X1           X2           X3           X4           X5
# SYMBOL       TSPAN6       TNMD         DPM1         SCYL3        C1orf112
# CD_I_LI_F_22 1.807444e+00 3.602160e-01 1.655355e+00 4.612769e-01 2.960698e-01
# CD_I_LI_F_29 1.375099e+00 1.868977e-01 1.470293e+00 3.548249e-01 4.571052e-01
# CD_I_LI_M_15 1.046922e+00 0.000000e+00 1.231819e+00 4.061349e-01 3.947304e-01
# CD_I_LI_M_24 1.569101e+00 0.000000e+00 1.356057e+00 3.447550e-01 2.302328e-01
# CD_I_LI_M_36 2.412461e+00 4.730471e-01 1.195666e+00 4.251135e-01 1.155138e-01
#              X6           X7           X8           X9           X10          ⋯
# SYMBOL       FGR          CFH          FUCA2        GCLC         NFYA         ⋯
# CD_I_LI_F_22 2.012083e+00 2.068933e+00 1.128181e+00 9.786043e-01 5.884043e-01 ⋯
# CD_I_LI_F_29 1.453504e+00 1.754955e+00 1.613129e+00 4.267503e-01 3.625660e-01 ⋯
# CD_I_LI_M_15 2.224107e+00 1.296238e+00 1.384375e+00 5.997394e-01 2.587169e-01 ⋯
# CD_I_LI_M_24 2.610643e+00 1.850258e+00 1.564470e+00 8.087634e-01 4.081987e-01 ⋯
# CD_I_LI_M_36 8.165720e-01 2.031182e+00 1.452564e+00 9.247032e-01 5.714828e-01 ⋯
#              X56572       X56573       X56574        X56575
# SYMBOL       PAUPAR       RP11-65B7.2  GIMAP1-GIMAP5 RP11-274B21.13
# CD_I_LI_F_22 4.131179e-02 0.000000e+00 0.000000e+00  7.316465e-01
# CD_I_LI_F_29 0.000000e+00 0.000000e+00 0.000000e+00  7.877799e-01
# CD_I_LI_M_15 0.000000e+00 0.000000e+00 0.000000e+00  1.730460e+00
# CD_I_LI_M_24 1.331003e-02 0.000000e+00 0.000000e+00  0.000000e+00
# CD_I_LI_M_36 0.000000e+00 0.000000e+00 0.000000e+00  0.000000e+00
#              X56576       X56577        X56578        X56579       X56580
# SYMBOL       AF127936.7   CH17-132F21.5 RP11-439M15.1 SNORA76A     LINC01144
# CD_I_LI_F_22 9.183766e-01 2.432572e-02  0.000000e+00  0.000000e+00 0.000000e+00
# CD_I_LI_F_29 1.335669e+00 5.691233e-02  0.000000e+00  0.000000e+00 0.000000e+00
# CD_I_LI_M_15 9.628040e-01 1.884629e-02  0.000000e+00  0.000000e+00 1.267155e-01
# CD_I_LI_M_24 1.717670e+00 3.635700e-02  0.000000e+00  0.000000e+00 5.467377e-02
# CD_I_LI_M_36 1.338568e+00 4.154589e-02  0.000000e+00  0.000000e+00 4.056578e-01
#              X56581
# OTHER_I_LI_F_53  0.000000e+00  0.000000e+00 1.806109e-01 0.000000e+00
# OTHER_I_LI_M_44  0.000000e+00  0.000000e+00 0.000000e+00 0.000000e+00
# OTHER_N_LI_M_79  0.000000e+00  0.000000e+00 3.725243e-02 0.000000e+00
# OTHER_N_NA_NA_63 0.000000e+00  0.000000e+00 0.000000e+00 0.000000e+00
# OTHER_U_LI_M_39  0.000000e+00  0.000000e+00 0.000000e+00 0.000000e+00
# OTHER_U_SI_F_54  0.000000e+00  0.000000e+00 2.456296e-01 2.085593e-01
# UC_I_LI_F_16     0.000000e+00  0.000000e+00 2.344411e-01 0.000000e+00
# UC_I_LI_F_19     0.000000e+00  0.000000e+00 8.654002e-02 0.000000e+00
# UC_I_LI_F_41     0.000000e+00  0.000000e+00 0.000000e+00 0.000000e+00
# UC_I_LI_F_45     0.000000e+00  0.000000e+00 0.000000e+00 0.000000e+00
# UC_I_LI_F_8      0.000000e+00  0.000000e+00 1.152100e-01 0.000000e+00
# UC_I_LI_M_1      0.000000e+00  0.000000e+00 9.635509e-02 0.000000e+00
# UC_I_LI_M_34     0.000000e+00  0.000000e+00 0.000000e+00 0.000000e+00
# UC_I_LI_M_9      0.000000e+00  4.240138e+00 0.000000e+00 0.000000e+00
# UC_M_LI_F_18     0.000000e+00  0.000000e+00 0.000000e+00 0.000000e+00
# UC_NA_LI_F_2     0.000000e+00  0.000000e+00 0.000000e+00 0.000000e+00
# UC_U_LI_F_40     0.000000e+00  0.000000e+00 0.000000e+00 0.000000e+00
# UC_U_LI_M_33     0.000000e+00  0.000000e+00 1.561658e-01 0.000000e+00
# UC_U_SI_F_17     0.000000e+00  0.000000e+00 0.000000e+00 0.000000e+00

# %% [markdown]
# We can now merge the `meta` and `expr2` dataframes so we have all the information in the same dataframe.

# %%
merged_data <- merge(meta, expr2, by.x=0, by.y=0)
head(merged_data)
# Out:
#   Row.names    title        disease.ch1 gender.ch1 inflammation_status.ch1
# 1 CD_I_LI_F_22 CD_I_LI_F_22 CD          female     inflamed
# 2 CD_I_LI_F_29 CD_I_LI_F_29 CD          female     inflamed
# 3 CD_I_LI_M_15 CD_I_LI_M_15 CD          male       inflamed
# 4 CD_I_LI_M_24 CD_I_LI_M_24 CD          male       inflamed
# 5 CD_I_LI_M_36 CD_I_LI_M_36 CD          male       inflamed
# 6 CD_I_LI_M_49 CD_I_LI_M_49 CD          male       inflamed
#   nancy_score.ch1 patient_age.ch1 site_taken.ch1  TSPAN6       TNMD         ⋯
# 1  1              43              large_intestine 1.807444e+00 3.602160e-01 ⋯
# 2 NA              25              large_intestine 1.375099e+00 1.868977e-01 ⋯
# 3  4              25              large_intestine 1.046922e+00 0.000000e+00 ⋯
# 4 NA              55              large_intestine 1.569101e+00 0.000000e+00 ⋯
# 5  0              73              large_intestine 2.412461e+00 4.730471e-01 ⋯
# 6  1              22              large_intestine 1.496762e+00 0.000000e+00 ⋯
#   PAUPAR       RP11-65B7.2  GIMAP1-GIMAP5 RP11-274B21.13 AF127936.7
# 1 4.131179e-02 0.000000e+00 0.000000e+00  7.316465e-01   9.183766e-01
# 2 0.000000e+00 0.000000e+00 0.000000e+00  7.877799e-01   1.335669e+00
# 3 0.000000e+00 0.000000e+00 0.000000e+00  1.730460e+00   9.628040e-01
# 4 1.331003e-02 0.000000e+00 0.000000e+00  0.000000e+00   1.717670e+00
# 5 0.000000e+00 0.000000e+00 0.000000e+00  0.000000e+00   1.338568e+00
# 6 0.000000e+00 0.000000e+00 0.000000e+00  0.000000e+00   0.000000e+00
#   CH17-132F21.5 RP11-439M15.1 SNORA76A.1   LINC01144    RP11-418H16.1
# 1 2.432572e-02  0.000000e+00  0.000000e+00 0.000000e+00 0.000000e+00
# 2 5.691233e-02  0.000000e+00  0.000000e+00 0.000000e+00 2.102050e-01
# 3 1.884629e-02  0.000000e+00  0.000000e+00 1.267155e-01 0.000000e+00
# 4 3.635700e-02  0.000000e+00  0.000000e+00 5.467377e-02 0.000000e+00
# 5 4.154589e-02  0.000000e+00  0.000000e+00 4.056578e-01 0.000000e+00
# 6 0.000000e+00  0.000000e+00  0.000000e+00 0.000000e+00 0.000000e+00

# %% [markdown]
# ### Visualizations using Basic Plots
# Let's explore the sample metadata by creating some plots using the `meta` dataframe.
#
# Let's first look at the distribution of patient ages in our dataset.

# %% [markdown]
# **Histograms:**

# %% [markdown]
# [`hist()`](https://www.datamentor.io/r-programming/histogram/) : generates a histogram

# %%
hist(meta$patient_age.ch1)
# Out:
# Plot with title "Histogram of meta$patient_age.ch1"

# %% [markdown]
# Next, generate a bar plot using [`barplot()`](https://www.statmethods.net/graphs/bar.html) of the gender.
#
# The input for `barplot()` is a table of counts for each condition, not a list of the conditions.
#
# Ex: instead of a list/vector with "female", "female", "female", "male", we need to use the [`table()`](https://www.statology.org/table-function-in-r/) function to get the counts, female: 3 and male: 1.

# %%
gender_table <- table(meta$gender.ch1)
gender_table
# Out:
# female   male
#     47     49

# %%
barplot(gender_table)
# Out:
# plot without title

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <h3>R Practice for basic visualizations: barplot</h3><br>
#
# <p>
#     Generate a stacked bar plot using <code>barplot()</code> of the disease and inflammation status. The x-axis should be divided by disease, and each disease will be subdivided into inflamed/uninflamed.
#
# Hints:
# - You can look here for [examples]((https://www.statmethods.net/graphs/bar.html))
# - Generate the counts table with disease and inflammation status
# - You can use the `beside=` parameter when calling `barplot()` so the groups aren't stacked on top of each other
# - Use the `legend=` parameter to include the legend in the plot
# - You can also add title (`main=`), x-axis label (`xlab=`), y-axis label (`ylab=`), colors (`col=`)
# </p>
#
#
# </div>

# %%
table(meta$disease.ch1, meta$inflammation_status.ch1)
# Out:
#
#           inflamed uninflamed
#   CD            19         15
#   Control        0         42
#   IBDu           1          0
#   OTHER          2          4
#   UC            10          3

# %%
barplot(table(meta$inflammation_status.ch1, meta$disease.ch1), beside=T,legend=T)
# Out:
# plot without title

# %% [markdown]
# **Scatter plots:**
#
# Let's make a scatter plot for the first two genes in our `expr2` data frame.
#
# [`plot()`](https://www.w3schools.com/r/r_graph_plot.asp) : general function that creates various plots depending on the input. We can input two vectors to generate a scatter plot
#
# Note: we just need the gene expression values, not the gene ID and symbol, so we need to subset the data by using `-c()` to designate which columns we don't need.

# %%
x1 <- expr2[,1]
x2 <- expr2[,2]

plot(x1,x2)
# Out:
# plot without title

# %% [markdown]
# We can add a title to our plot with the genes by using [`paste()`](https://www.digitalocean.com/community/tutorials/paste-in-r). `paste()` allows you to combine variables and/or strings into a single string.

# %%
x1 <- expr2[,1]
x2 <- expr2[,2]

x_gene <- names(expr2[1])
y_gene <- names(expr2[2])

plot(x1,x2, xlab=x_gene, ylab=y_gene, main=paste(x_gene,'vs',y_gene))
# Out:
# Plot with title "TSPAN6 vs TNMD"

# %% [markdown]
# We can also plot data using gene names. Let's plot FGR and GCLC.

# %%
x1 <- expr2$FGR
x2 <- expr2$GCLC

plot(x1,x2, xlab='FGR', ylab='GCLC',main='FGR vs GCLC')
# Out:
# Plot with title "FGR vs GCLC"

# %% [markdown]
# **Boxplots**
#
# We can also compare the expression of certain genes between certain groups using boxplots.
#
# [`boxplot()`](https://www.tutorialspoint.com/r/r_boxplots.htm) : generates a boxplot
#
# Use `boxplot()` to plot the TYK2 gene expression by disease.

# %%
boxplot(TYK2 ~ disease.ch1, merged_data)
# Out:
# plot without title

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <h3>R Practice for basic visualizations: boxplot</h3><br>
#     <p>Generate a boxplot comparing STAT3 between Control vs CD vs UC samples only
#
# Hints:
# - You can look here for [examples](https://www.statmethods.net/graphs/boxplot.html)
# - Look at the [`subset=`](https://stackoverflow.com/questions/38908230/how-do-i-subset-a-box-plots-in-r) parameter in boxplot() which uses the format `dataframe$column %in% c(variable1, variable2)`
# - Can also add title, x and y labels, colors
#    </p>
# </div>

# %%
boxplot(STAT3 ~ disease.ch1, merged_data, subset=disease.ch1 %in% c('Control','CD','UC'))
# Out:
# plot without title

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <p>You should have 3 boxes for CD, Control and UC showing the expression of STAT3. </p>
#
# </div>

# %% [markdown]
# ### Visualizations using ggplot

# %%
library('ggplot2')

# %% [markdown]
# [ggplot2](https://datacarpentry.org/R-ecology-lesson/04-visualization-ggplot2.html) works primarily with dataframes. We have to supply ggplot with a dataframe. As we go through ggplot, a key thing to notice is how the plot can continually be enhaanced by adding layers and themes (generally indicated by a ```+``` sign and a following statement) to an existing plot.
#
# Here is a ggplot data visualization cheat sheet for your own reference: https://github.com/rstudio/cheatsheets/blob/main/data-visualization-2.1.pdf

# %% [markdown]
# Now let's initialize a basic ggplot with our `merged_data` data frame, using the TYK2 and STAT3 columns of data. The aes() function is what we will use to specify the X and Y axes

# %%
ggplot(merged_data, aes(x=TYK2, y=STAT3))
# Out:
# plot without title

# %% [markdown]
# Do you see a blank ggplot? If so, don't worry, you did this step correctly. While we have x and y labels that match the columns we initialized the plot with, we don't see any plotted data. This is because ggplot does not make assumptions about the plot you are meaning to draw. Initializing the ggplot only tells ggplot what dataframe and what x and y columns from the dataframe should be used.
#
# Now let's make a scatterplot. We will do this by adding on a layer using ```geom_point()```.

# %%
ggplot(merged_data, aes(x=TYK2, y=STAT3)) +
    geom_point()
# Out:
# plot without title

# %% [markdown]
# From here, we can add on a smoothing layer using the method "lm" to draw a line of best fit.

# %%
ggplot(merged_data, aes(x=TYK2, y=STAT3)) +
    geom_point() +
    geom_smooth(method='lm')
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# plot without title

# %% [markdown]
# We can also adjust the x and y limits.

# %%
ggplot(merged_data, aes(x=TYK2, y=STAT3)) + 
    geom_point() + 
    geom_smooth(method='lm') + 
    xlim(c(0, 5)) + 
    ylim(c(0, 5))
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# plot without title

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <h3>R Practice for ggplot</h3><br>
#
# Generate a box plot like we did before (STAT3 expression for Control, CD, UC) but use ggplot this time (`geom_boxplot()`).
# <br>
#
# You can look here for [examples](http://www.sthda.com/english/wiki/ggplot2-box-plot-quick-start-guide-r-software-and-data-visualization)
#
# <br>
# <p>Suggestions to include:</p>
# <ul>
# <li>Ordering the box plots (Control, CD, UC)</li>
#     <li>Labels for title, x and y axis (<code>labs()</code>)</li>
# <li>Colors for each disease group</li>
#     <li>Add points for the samples (look at <code>geom_point()</code> or <code>geom_jitter()</code>)</li>
# <li>Font size</li>
# <li>ggplot theme</li>
#     </ul>
#
# </div>

# %%
ggplot(subset(merged_data, disease.ch1 %in% c('Control','CD','UC')), 
       aes(y=STAT3, x=reorder(disease.ch1,STAT3), fill=disease.ch1)) +
    scale_fill_brewer(palette="Blues") + 
    geom_boxplot() +
    geom_jitter(shape=16, position=position_jitter(0.2)) +
    theme_minimal() +
    labs(title='STAT3 by Disease', x='Disease')
# Out:
# plot without title

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# You should have three boxes showing the expression of STAT3 for Control, Disease and UC.
#
# </div>

# %% [markdown]
# ### [Pheatmap](https://www.rdocumentation.org/packages/COMPASS/versions/1.10.2/topics/pheatmap)
# Pheatmap enables you to draw clustered heatmaps, where you can control more of the graphical parameters.

# %%
library(pheatmap)

# %% [markdown]
# Let's see how the top genes identified in this [meta-analysis paper](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8440637/) perform in our dataset.
# First, read in the file `data/PMC8440637_top_genes.txt` into a dataframe `gene_table` so we can see the top 10 up- and top 10 down-regulated genes from this paper.

# %%
# Get list of top genes from file
gene_table <- read.table('PMC8440637_top_genes.txt',sep='\t',header=TRUE)
genes <- as.vector(gene_table$Symbol)
genes
# Out:
#  [1] "LCN2"   "DUOXA2" "PI3"    "CXCL8"  "MMP3"   "REG3A"  "CHI3L1" "MMP7"
#  [9] "DUOX2"  "MMP9"   "AQP8"   "CLDN8"  "HMGCS2" "UGT2A3" "GUCA2B" "PCK1"
# [17] "TRPM6"  "CHP2"   "ANPEP"  "ADH1C"

# %% [markdown]
# Now let's create a new data frame `data` by getting the expression for these genes from the `expr2` data frame.
#
# The pheatmap function typically has the genes as rows and samples as columns, so let's also use `t()` and `data.frame()` to transpose our dataframe into the correct format.

# %%
data <- data.frame(t(expr2[,genes]))
head(data)
# Out:
#        CD_I_LI_F_22 CD_I_LI_F_29 CD_I_LI_M_15 CD_I_LI_M_24 CD_I_LI_M_36
# LCN2   3.767252     2.7669918    0.9342957    1.760522     3.2825152
# DUOXA2 2.524936     1.2455974    0.1287080    1.605984     0.8910878
# PI3    5.055456     0.6766387    0.5636727    2.340102     3.2999285
# CXCL8  1.711809     3.1346025    0.3448811    2.198842     0.4449525
# MMP3   1.581164     0.1327496    2.6852045    4.394150     0.6045968
# REG3A  1.593473     5.9226395    1.4909606    3.135199     1.4683305
#        CD_I_LI_M_49 CD_I_LI_M_5 CD_I_SI_F_20 CD_I_SI_F_25 CD_I_SI_F_3 ⋯
# LCN2   1.2004556    3.5037991   2.54495856   3.84286583   5.075755    ⋯
# DUOXA2 0.0000000    1.5094562   0.06973406   2.88346463   2.736456    ⋯
# PI3    1.3874637    2.5014523   1.79307527   3.43728820   3.249428    ⋯
# CXCL8  2.5070187    0.2184614   0.33741893   0.04386089   0.529090    ⋯
# MMP3   0.3051378    0.4273062   0.19165371   0.45257322   1.156274    ⋯
# REG3A  3.3269048    3.4596204   1.93195755   6.23624042   6.713191    ⋯
#        UC_I_LI_F_45 UC_I_LI_F_8 UC_I_LI_M_1 UC_I_LI_M_34 UC_I_LI_M_9
# LCN2   4.0503561    4.2534273   4.0234266   0.5408802    2.9161153
# DUOXA2 2.8734968    3.3287808   3.2693978   0.1249625    2.5423970
# PI3    4.6615222    5.5048192   5.4509955   2.8623666    4.4129910
# CXCL8  0.4795102    0.5139374   0.3108877   2.6645580    0.3491529
# MMP3   1.7601312    2.2953319   1.2756309   4.9263765    0.8560650
# REG3A  1.6058756    3.1035188   2.1514912   1.6657918    3.4381334
#        UC_M_LI_F_18 UC_NA_LI_F_2 UC_U_LI_F_40 UC_U_LI_M_33 UC_U_SI_F_17
# LCN2   3.4121109    0.2928174    5.166898     3.9861077    1.4318316
# DUOXA2 1.3416813    0.1630827    4.316530     3.6515332    0.5429619
# PI3    2.5366211    1.9559029    5.288540     3.9945426    1.7929471
# CXCL8  0.0283921    1.3305491    1.203474     0.4408683    0.1292003
# MMP3   0.1997914    5.6102993    1.265877     2.6463946    0.3924042
# REG3A  4.2587737    2.2032840    4.934021     4.0010700    8.7823950

# %% [markdown]
# Plot the gene expression using `pheatmap()`

# %%
pheatmap(data)
# Out:
# plot without title

# %% [markdown]
# Let's increase the size so the heatmap isn't compressed using `options(repr.plot.width = #, repr.plot.height = #)`.

# %%
options(repr.plot.width = 14, repr.plot.height = 8)
pheatmap(data)
# Out:
# plot without title

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <h3>R Practice for pheatmap</h3><br>
#     <p>Let's change some of the parameters so we can try to explain what we're seeing with the data.</p>
# <br>
#
# You can look here for [examples](https://davetang.org/muse/2018/05/15/making-a-heatmap-in-r-with-the-pheatmap-package/)
#
# <ul>
# <li>Subset the samples so you're only showing the Control, CD and UC samples</li>
# <li>Add annotations to the samples using the meta data frame (try adding one or more of the columns to see if any of the characteristics describe the change in gene expression for the samples)</li>
# <li>Add annotations to the genes to show whether they were classified as up or down regulated (Hint: look in the file for the top genes)</li>
# <li>Can also change some of the aesthetics</li>
# </ul>
# </div>

# %% [markdown]
# 1. Create a new dataframe `sample_annotations` with only the Control, CD and UC samples from `meta`
#
# *Hint: use this format `dataframe$column %in% c(variable1, variable2)`*

# %%
# Sample annotations
sample_annotations <- meta[meta$disease.ch1 %in% c('Control','CD','UC'),]
colnames(sample_annotations) <- c('title','disease', 'gender', 'inflammation_status', 'nancy_score', 
                                  'patient_age', 'site_taken')
sample_annotations <- sample_annotations[with(sample_annotations, order(disease, inflammation_status)),]
head(sample_annotations)
# Out:
#              title        disease gender inflammation_status nancy_score
# CD_I_SI_F_3  CD_I_SI_F_3  CD      female inflamed             4
# CD_I_SI_M_4  CD_I_SI_M_4  CD      male   inflamed            NA
# CD_I_LI_M_5  CD_I_LI_M_5  CD      male   inflamed             2
# CD_I_SI_M_10 CD_I_SI_M_10 CD      male   inflamed             4
# CD_I_LI_M_15 CD_I_LI_M_15 CD      male   inflamed             4
# CD_I_SI_F_20 CD_I_SI_F_20 CD      female inflamed             0
#              patient_age site_taken
# CD_I_SI_F_3  56          small_intestine
# CD_I_SI_M_4  33          small_intestine
# CD_I_LI_M_5  28          large_intestine
# CD_I_SI_M_10 28          small_intestine
# CD_I_LI_M_15 25          large_intestine
# CD_I_SI_F_20 43          small_intestine

# %% [markdown]
# 2. Create a new dataframe `data2` with only the Control, CD and UC samples from `data`
#
# *Hint: get a list of sample IDs for Control, CD and UC and use those sample IDs to filter `data`*

# %%
# Subset samples to keep Control, CD and UC
samples_to_keep <- rownames(sample_annotations)
data2 <- data[,samples_to_keep]
head(data2)
# Out:
#        CD_I_SI_F_3 CD_I_SI_M_4 CD_I_LI_M_5 CD_I_SI_M_10 CD_I_LI_M_15
# LCN2   5.075755    3.8551669   3.5037991   4.306377     0.9342957
# DUOXA2 2.736456    1.6725066   1.5094562   2.926784     0.1287080
# PI3    3.249428    0.9980329   2.5014523   4.053957     0.5636727
# CXCL8  0.529090    0.1309432   0.2184614   1.267654     0.3448811
# MMP3   1.156274    0.1405043   0.4273062   4.153445     2.6852045
# REG3A  6.713191    4.7546930   3.4596204   7.212140     1.4909606
#        CD_I_SI_F_20 CD_I_LI_F_22 CD_M_LI_M_23 CD_I_LI_M_24 CD_I_SI_F_25 ⋯
# LCN2   2.54495856   3.767252     4.4506311    1.760522     3.84286583   ⋯
# DUOXA2 0.06973406   2.524936     1.7662297    1.605984     2.88346463   ⋯
# PI3    1.79307527   5.055456     4.8870278    2.340102     3.43728820   ⋯
# CXCL8  0.33741893   1.711809     0.8322828    2.198842     0.04386089   ⋯
# MMP3   0.19165371   1.581164     0.5268682    4.394150     0.45257322   ⋯
# REG3A  1.93195755   1.593473     1.7624697    3.135199     6.23624042   ⋯
#        UC_I_LI_M_9 UC_I_LI_F_16 UC_M_LI_F_18 UC_I_LI_F_19 UC_I_LI_M_34
# LCN2   2.9161153   1.4389532    3.4121109    3.111589     0.5408802
# DUOXA2 2.5423970   0.8808293    1.3416813    2.302065     0.1249625
# PI3    4.4129910   1.4467754    2.5366211    2.519550     2.8623666
# CXCL8  0.3491529   0.5247694    0.0283921    2.008095     2.6645580
# MMP3   0.8560650   0.1970919    0.1997914    1.648799     4.9263765
# REG3A  3.4381334   2.0087508    4.2587737    4.085904     1.6657918
#        UC_I_LI_F_41 UC_I_LI_F_45 UC_U_SI_F_17 UC_U_LI_M_33 UC_U_LI_F_40
# LCN2   1.2696173    4.0503561    1.4318316    3.9861077    5.166898
# DUOXA2 0.2232499    2.8734968    0.5429619    3.6515332    4.316530
# PI3    3.1121321    4.6615222    1.7929471    3.9945426    5.288540
# CXCL8  4.5061650    0.4795102    0.1292003    0.4408683    1.203474
# MMP3   0.1614247    1.7601312    0.3924042    2.6463946    1.265877
# REG3A  2.4558382    1.6058756    8.7823950    4.0010700    4.934021

# %% [markdown]
# 3. Create a new dataframe `gene_annotations` with the regulation information from the `gene_table` dataframe.
#
# Hints:
# - Subset `gene_table` so it only has the Symbol and Regulation columns
# - Change the rownames to the Symbol using `rownames(gene_annotations) <-`
# - Remove the Symbol column after setting the rownames
#
# *The resulting dataframe should have the genes as the rownames and one column for Regulation with up/down*

# %%
# Gene annotations
gene_annotations <- gene_table[,c(1,5)]
rownames(gene_annotations) <- gene_annotations$Symbol
gene_annotations <- gene_annotations[-1]
colnames(gene_annotations) <- c('regulation')
head(gene_annotations)
# Out:
#        regulation
# LCN2   up
# DUOXA2 up
# PI3    up
# CXCL8  up
# MMP3   up
# REG3A  up

# %% [markdown]
# 4. Plot the data using `pheatmap()`.
#
# Set the row (gene) and column (sample) annotations using the parameters `annotation_row=` and `annotation_col=`.
#
# For the sample annotations, try different subsets of the columns to see which of the sample metadata best explains the heatmap. Ex: you can try just gender, gender and disease, or other combinations.

# %%
options(repr.plot.width = 18, repr.plot.height = 10)
pheatmap(data2, cutree_rows = 2, annotation_col=sample_annotations[c(2,4)], annotation_row=gene_annotations,
        fontsize_row=15, main='Top IBD Genes in Control, CD and UC Samples')
# Out:
# plot without title

# %% [markdown]
# Plot 2. Remove column clustering, only use UC samples

# %%
options(repr.plot.width = 18, repr.plot.height = 10)
samples_to_keep <- rownames(sample_annotations[sample_annotations$disease %in% c('UC'),])
data3 <- data2[,samples_to_keep]
pheatmap(data3, cuttree_rows=2, cluster_cols=F, 
         annotation_col=sample_annotations[c(2,4)], annotation_row=gene_annotations,
        fontsize_row=15, main='Top IBD Genes in Control, CD and UC Samples')
# Out:
# plot without title

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <strong>Question:</strong> What results did you find from your heatmap? Do the results support the findings from the meta-analysis done in the paper that these are the top up- and down-regulated genes in IBD?
# </div>

# %% [markdown]
# *Type your findings here*

# %% [markdown]
# ### Session Info

# %%
sessionInfo()
# Out:
# R version 4.2.2 (2022-10-31)
# Platform: x86_64-apple-darwin13.4.0 (64-bit)
# Running under: macOS Big Sur ... 10.16
#
# Matrix products: default
# BLAS/LAPACK: /opt/anaconda3/envs/r_env/lib/libopenblasp-r0.3.21.dylib
#
# locale:
# [1] en_US.UTF-8/en_US.UTF-8/en_US.UTF-8/C/en_US.UTF-8/en_US.UTF-8
#
# attached base packages:
# [1] stats4    stats     graphics  grDevices utils     datasets  methods
# [8] base
#
# other attached packages:
#  [1] pheatmap_1.0.12           ggplot2_3.4.0
#  [3] EnsDb.Hsapiens.v79_2.99.0 ensembldb_2.22.0
#  [5] AnnotationFilter_1.22.0   GenomicFeatures_1.50.3
#  [7] AnnotationDbi_1.60.0      Biobase_2.58.0
#  [9] GenomicRanges_1.50.2      GenomeInfoDb_1.34.6
# [11] IRanges_2.32.0            S4Vectors_0.36.1
# [13] BiocGenerics_0.44.0
#
# loaded via a namespace (and not attached):
#  [1] MatrixGenerics_1.10.0       httr_1.4.4
#  [3] splines_4.2.2               bit64_4.0.5
#  [5] jsonlite_1.8.4              assertthat_0.2.1
#  [7] BiocFileCache_2.6.0         blob_1.2.3
#  [9] GenomeInfoDbData_1.2.9      Rsamtools_2.14.0
# [11] yaml_2.3.6                  progress_1.2.2
# [13] pillar_1.8.1                RSQLite_2.2.20
# [15] lattice_0.20-45             glue_1.6.2
# [17] uuid_1.1-0                  digest_0.6.31
# [19] RColorBrewer_1.1-3          XVector_0.38.0
# [21] colorspace_2.0-3            htmltools_0.5.4
# [23] Matrix_1.5-3                XML_3.99-0.13
# [25] pkgconfig_2.0.3             biomaRt_2.54.0
# [27] zlibbioc_1.44.0             scales_1.2.1
# [29] BiocParallel_1.32.5         tibble_3.1.8
# [31] mgcv_1.8-41                 KEGGREST_1.38.0
# [33] farver_2.1.1                generics_0.1.3
# [35] ellipsis_0.3.2              withr_2.5.0
# [37] cachem_1.0.6                SummarizedExperiment_1.28.0
# [39] repr_1.1.4                  lazyeval_0.2.2
# [41] cli_3.5.0                   magrittr_2.0.3
# [43] crayon_1.5.2                memoise_2.0.1
# [45] evaluate_0.19               fansi_1.0.3
# [47] nlme_3.1-161                xml2_1.3.3
# [49] tools_4.2.2                 prettyunits_1.1.1
# [51] hms_1.1.2                   BiocIO_1.8.0
# [53] lifecycle_1.0.3             matrixStats_0.63.0
# [55] stringr_1.5.0               munsell_0.5.0
# [57] DelayedArray_0.24.0         Biostrings_2.66.0
# [59] compiler_4.2.2              rlang_1.0.6
# [61] grid_4.2.2                  RCurl_1.98-1.9
# [63] pbdZMQ_0.3-8                IRkernel_1.3.1
# [65] rjson_0.2.21                rappdirs_0.3.3
# [67] labeling_0.4.2              bitops_1.0-7
# [69] base64enc_0.1-3             gtable_0.3.1
# [71] restfulr_0.0.15             codetools_0.2-18
# [73] DBI_1.1.3                   curl_4.3.3
# [75] R6_2.5.1                    GenomicAlignments_1.34.0
# [77] dplyr_1.0.10                rtracklayer_1.58.0
# [79] fastmap_1.1.0               bit_4.0.5
# [81] utf8_1.2.2                  filelock_1.0.2
# [83] ProtGenerics_1.30.0         stringi_1.7.8
# [85] parallel_4.2.2              IRdisplay_1.1
# [87] Rcpp_1.0.9                  vctrs_0.5.1
# [89] png_0.1-8                   dbplyr_2.2.1
# [91] tidyselect_1.2.0
